# %% [markdown]
# # Overview
#
# Quick import smoke test.

# %%
import os
os.environ.setdefault('SODA_BASE','https://data.sfgov.org/resource')
# os.environ['SODA_APP_TOKEN']='...optional...'

# %%
from scripts.permit import building, plumbing, electrical, addenda, complaint
from scripts import contractor
print('ok')
