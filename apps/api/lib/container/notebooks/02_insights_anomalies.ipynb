# %% [markdown]
# # Insights + anomalies (placeholders)
#
# These modules are stubs but runnable.

# %%
from scripts.insights import contractors as ic
from scripts.anomalies import contractors as ac
print(ic.run(ic.InputSpec(request_id='demo')).rows[0].row)
print(ac.run(ac.InputSpec(request_id='demo')).rows[0].row)
