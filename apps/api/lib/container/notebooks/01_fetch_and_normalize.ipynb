# %% [markdown]
# # Fetch + normalize
#
# Pull a small sample from SODA and normalize contractor + address fields.

# %%
from scripts.permit import building
spec = building.InputSpec(request_id='demo', soql_params={'$limit': 10, '$order': 'status_date DESC'})
out = building.run(spec)
print(out.stats)
print(out.rows[0].row.get('contractor_name_norm'))
print(out.rows[0].row.get('address_norm'))
