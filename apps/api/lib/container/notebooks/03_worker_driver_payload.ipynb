# %% [markdown]
# # Worker driver input payload
#
# This is what the Worker typically writes into `/workspace/input.json`.

# %%
import json
payload = {
  'requestId': 'demo',
  'payload': {
    'permitTypes': ['building','plumbing'],
    'soql': {'$limit': 10},
    'includeInsights': True,
    'includeAnomalies': True,
    'includeContractorContacts': False
  }
}
print(json.dumps(payload, indent=2))
